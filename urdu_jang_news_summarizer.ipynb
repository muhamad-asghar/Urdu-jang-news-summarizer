# %%
import torch
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu")
    print("No GPU available, using CPU instead.")
# Out:
# Using GPU: Tesla T4

# %%
import requests
from bs4 import BeautifulSoup
import json
import os

url = 'https://jang.com.pk/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
main_story_home_divs = soup.find_all('div', class_='main-story-home')
a_tags = [a['href'] for div in main_story_home_divs for a in div.find_all('a', href=True)]

print("Extracted <a> tags:")
for a_tag in a_tags:
    print(a_tag)
# Out:
# Extracted <a> tags:
# https://jang.com.pk/news/1421166
# https://jang.com.pk/news/1421175
# https://jang.com.pk/news/1421176
# https://jang.com.pk/news/1421181
# https://jang.com.pk/news/1421180
# https://jang.com.pk/news/1421164
# https://jang.com.pk/news/1421167
# https://jang.com.pk/news/1421174
# https://jang.com.pk/news/1421193
# https://jang.com.pk/news/1421184
# https://jang.com.pk/news/1421170
# https://jang.com.pk/news/1421177
# https://jang.com.pk/news/1421163
# https://jang.com.pk/news/1421146
# https://jang.com.pk/news/1421183
# https://jang.com.pk/news/1421149
# https://jang.com.pk/news/1421165
# https://jang.com.pk/news/1421159
# https://jang.com.pk/news/1421185
# https://jang.com.pk/news/1421187
# https://jang.com.pk/news/1421179
# https://jang.com.pk/news/1421174
# https://jang.com.pk/news/1421171
# https://jang.com.pk/news/1421158
# https://jang.com.pk/news/1421155
# https://jang.com.pk/news/1421151
# https://jang.com.pk/news/1421148
# https://jang.com.pk/news/1421142
# https://jang.com.pk/news/1421182
# https://jang.com.pk/news/1421165
# https://jang.com.pk/news/1421162
# https://jang.com.pk/news/1421153
# https://jang.com.pk/news/1421152
# https://jang.com.pk/news/1421147
# https://jang.com.pk/news/1421123
# https://jang.com.pk/news/1420929
# https://jang.com.pk/news/1420923
# https://jang.com.pk/news/1420910
# https://jang.com.pk/news/1421170
# https://jang.com.pk/news/1421168
# https://jang.com.pk/news/1421146
# https://jang.com.pk/news/1421124
# https://jang.com.pk/news/1420932
# https://jang.com.pk/news/1420933
# https://jang.com.pk/news/1420922
# https://jang.com.pk/news/1420908
# https://jang.com.pk/news/1420903
# https://jang.com.pk/news/1420900
# https://jang.com.pk/news/1421172
# https://jang.com.pk/news/1421177
# https://jang.com.pk/news/1421135
# https://jang.com.pk/news/1421134
# https://jang.com.pk/news/1421129
# https://jang.com.pk/news/1421115
# https://jang.com.pk/news/1421112
# https://jang.com.pk/news/1421020
# https://jang.com.pk/news/1420940
# https://jang.com.pk/news/1420927
# https://jang.com.pk/news/1420939
# https://jang.com.pk/news/1421021
# https://jang.com.pk/news/1420938
# https://jang.com.pk/news/1421022
# https://jang.com.pk/news/1421023
# https://jang.com.pk/news/1421024
# https://jang.com.pk/news/1421025
# https://jang.com.pk/news/1421026
# https://jang.com.pk/news/1421027
# https://jang.com.pk/news/1421028

# %%
os.makedirs('jang_articles', exist_ok=True)

# %%
for idx, a_tag in enumerate(a_tags, start=1):
    try:
        print(f"Processing {a_tag}")
        response = requests.get(a_tag)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all p tags within the article
        p_tags = soup.find_all('p')

        if p_tags:
            # Extract text from all p tags
            all_text = [p.get_text(strip=True) for p in p_tags]

            # Create a dictionary with paragraph numbers as keys
            data = {f"p{i + 1}": paragraph for i, paragraph in enumerate(all_text)}
            json_data = json.dumps(data, indent=4, ensure_ascii=False)
            with open(f'jang_articles/article_{idx}.json', 'w', encoding='utf-8') as f:
                f.write(json_data)

            print(f'Data has been saved to jang_articles/article_{idx}.json')
        else:
            print(f"No p tags found for {a_tag}")
    except Exception as e:
        print(f"Error processing {a_tag}: {e}")
# Out:
# Processing https://jang.com.pk/news/1421166
# Data has been saved to jang_articles/article_1.json
# Processing https://jang.com.pk/news/1421175
# Data has been saved to jang_articles/article_2.json
# Processing https://jang.com.pk/news/1421176
# Data has been saved to jang_articles/article_3.json
# Processing https://jang.com.pk/news/1421181
# Data has been saved to jang_articles/article_4.json
# Processing https://jang.com.pk/news/1421180
# Data has been saved to jang_articles/article_5.json
# Processing https://jang.com.pk/news/1421164
# Data has been saved to jang_articles/article_6.json
# Processing https://jang.com.pk/news/1421167
# Data has been saved to jang_articles/article_7.json
# Processing https://jang.com.pk/news/1421174
# Data has been saved to jang_articles/article_8.json
# Processing https://jang.com.pk/news/1421193
# Data has been saved to jang_articles/article_9.json
# Processing https://jang.com.pk/news/1421184
# Data has been saved to jang_articles/article_10.json
# Processing https://jang.com.pk/news/1421170
# Data has been saved to jang_articles/article_11.json
# Processing https://jang.com.pk/news/1421177
# Data has been saved to jang_articles/article_12.json
# Processing https://jang.com.pk/news/1421163
# Data has been saved to jang_articles/article_13.json
# Processing https://jang.com.pk/news/1421146
# Data has been saved to jang_articles/article_14.json
# Processing https://jang.com.pk/news/1421183
# Data has been saved to jang_articles/article_15.json
# Processing https://jang.com.pk/news/1421149
# Data has been saved to jang_articles/article_16.json
# Processing https://jang.com.pk/news/1421165
# Data has been saved to jang_articles/article_17.json
# Processing https://jang.com.pk/news/1421159
# Data has been saved to jang_articles/article_18.json
# Processing https://jang.com.pk/news/1421185
# Data has been saved to jang_articles/article_19.json
# Processing https://jang.com.pk/news/1421187
# Data has been saved to jang_articles/article_20.json
# Processing https://jang.com.pk/news/1421179
# Data has been saved to jang_articles/article_21.json
# Processing https://jang.com.pk/news/1421174
# Data has been saved to jang_articles/article_22.json
# Processing https://jang.com.pk/news/1421171
# Data has been saved to jang_articles/article_23.json
# Processing https://jang.com.pk/news/1421158
# Data has been saved to jang_articles/article_24.json
# Processing https://jang.com.pk/news/1421155
# Data has been saved to jang_articles/article_25.json
# Processing https://jang.com.pk/news/1421151
# Data has been saved to jang_articles/article_26.json
# Processing https://jang.com.pk/news/1421148
# Data has been saved to jang_articles/article_27.json
# Processing https://jang.com.pk/news/1421142
# Data has been saved to jang_articles/article_28.json
# Processing https://jang.com.pk/news/1421182
# Data has been saved to jang_articles/article_29.json
# Processing https://jang.com.pk/news/1421165
# Data has been saved to jang_articles/article_30.json
# Processing https://jang.com.pk/news/1421162
# Data has been saved to jang_articles/article_31.json
# Processing https://jang.com.pk/news/1421153
# Data has been saved to jang_articles/article_32.json
article_files = sorted([filename for filename in os.listdir('jang_articles') if filename.endswith('.json')],
                      key=natural_sort_key)

for filename in article_files:
    filepath = os.path.join('jang_articles', filename)
    with open(filepath, 'r', encoding='utf-8') as f:
        json_data = json.load(f)
    print(f"Content of {filename}:")
    print(json.dumps(json_data, indent=4, ensure_ascii=False))
    print("-" * 20)
# Out:
# Content of article_1.json:
# {
#     "p1": "",
#     "p2": "",
#     "p3": "",
#     "p4": "",
#     "p5": "وزیر دفاع خواجہ آصف نے کہا ہے کہ  پی ٹی آئی کبھی سول نافرمانی اور کبھی مذاکرات کی بات کرتی ہے۔ جو ماحول پی ٹی آئی نے بنادیا ہے اس میں کوئی مذاکرات نتیجہ خیز نہیں ہوسکتے۔",
#     "p6": "سیالکوٹ میں جیو نیوز سے خصوصی گفتگو میں خواجہ آصف نے کہا کہ  پی ٹی آئی سے مذاکرات شروع ہونے کی کوئی بات ان کے علم میں نہیں۔ مذاکرات کے بارے میں  جو بیانات آرہے ہیں وہ پی ٹی آئی کی جانب سے آرہے ہیں، حکومت کی جانب سے کوئی بیان نہیں آیا ہے۔",
#     "p7": "خواجہ آصف کا کہنا تھا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔",
#     "p8": "خواجہ آصف نے کہا کہ ان کی اطلاع ہے کہ فیض حمید کیخلاف فرد جرم ٹھوس شواہد پر مبنی ہے۔",
#     "p9": "انہوں نے مزید کہا کہ سیاسی حالات معمول پر ہیں۔ مختلف پارٹیاں ہیں یہاں ایک دوسرے سے گلے شکوے ہوتے رہتے ہیں۔ پارٹیوں کے اپنے ٹارگٹ ہوتے ہیں جسے پانے کیلئے ایسے بیانات آتے رہتے ہیں۔",
#     "p10": "یونان کشتی حادثے سے متعلق بات کرتے ہوئے خواجہ آصف نے کہا کہ یونان کشتی حادثہ ہمارے سسٹم کی ناکامی  ہے۔ حکومت کا حصہ ہوتے ہوئے سمجھتا ہوں اس معاملے کا حل اولین ترجیح ہونا چاہیے۔ لوگ جائیدادیں بیچ کر اپنے بچوں کو بھیجتے ہیں، چند ماہ بعد ان کے بچوں کی لاش آتی ہے یا جیلوں میں ہوتے ہیں۔",
#     "p11": "خواجہ آصف نے کہا کہ سارا سسٹم بردہ فروشوں سے ملا ہوا ہے، یہ لوگ بچوں سے جو پیسے لیتے ہیں وہ اوپر تک بانٹے جاتے ہیں۔ جو لوگ ان کو روکنے والے ہیں وہ بھی پیسے لیتے ہیں، جس سسٹم کو انہیں  روکنا ہے وہ کمپرومائزڈ ہے، میں ہر سطح پر اس معاملے پر آواز اٹھاؤں گا، اسمبلی میں بھی بولوں گا۔",
#     "p12": "سی ای او واٹر کارپوریشن انجینئر صلاح الدین احمد  نے کہا کہ  بی آر ٹی ٹریک کے نیچے 1958 اور1971 میں ڈالی گئی لائنیں ہیں، بی آر ٹی انتظامیہ کو 35 ملین روپے ہرجانہ ادا کرنے کا کہا ہے۔",
#     "p13": "سینٹرل ڈیولپمنٹ ورکنگ پارٹی (سی ڈی ڈبلیو پی) نے 422 ارب 70 کروڑ لاگت کے 15 ترقیاتی منصوبے منظور کرلیے۔",
#     "p14": "چیئرمین پیپلز پارٹی بلاول بھٹو زرداری نے سانحہِ آرمی پبلک اسکول پشاور کے شہدا کو خراجِ عقیدت پیش کیا۔",
#     "p15": "ایکسپو سینٹر کراچی میں جاری پانچ روزہ عالمی کتب میلے کے دوسرے روز بھی شہریوں کی بڑی تعداد نے کتب میلے میں شرکت کی۔صبح سے ہی بڑی بھی شہریوں کی بڑی تعداد نے شرکت کی۔ صبح سے ہی اسکولز، کالجز اور یونیورسٹی و مدارس کے طلبہ سمیت سماجی تنظیموں، ادبی اور سرکاری شخصیات نے بھی کتب میلے کا دورہ کیا۔",
#     "p16": "محسن نقوی نے کہا کہ پاکستان سفارتکاروں کی حفاظت کیلئے اسپیشل پروٹیکشن یونٹ قائم کر رہا ہے۔",
#     "p17": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔",
#     "p18": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔",
#     "p19": "اسپیکر قومی اسمبلی سردار ایاز صادق نے کہا ہے کہ 16 دسمبر 2014ء کو طلباء اور اساتذہ کی قربانی نے دہشت گردی کے خاتمے کےلیے پوری قوم کو متحد کیا۔",
#     "p20": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔",
#     "p21": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔",
#     "p22": "چیئرمین پبلک اکاؤنٹس کمیٹی سندھ نثار کھوڑو نے کہا ہے کہ وفاقی حکومت آئین کی خلاف ورزیوں سے باز رہے۔",
#     "p23": "وزیراعظم شہباز شریف کی فوکل پرسن عائشہ رضا فاروق نے کہا ہے کہ انسداد پولیو مہم کے ذریعے 4 کروڑ 40 لاکھ بچوں کو قطرےپلائے جائیں گے۔",
#     "p24": "وزیراعظم شہبازشریف کے مشیر رانا ثناء اللّٰہ نے کہا ہے کہ پی ٹی آئی کی صوبائی حکومت 3 بار اسلام آباد پر حملہ آور ہوچکی ہے۔",
#     "p25": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔",
#     "p26": "وزیراعظم شہباز شریف نے رواں سال پولیو کے 60 کیسز سامنے آنےکو انتہائی تشویشناک اور حکومت کے لیے چیلنج قرار دیا ہے۔",
#     "p27": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔ ۔",
#     "p28": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔ \n\n۔",
#     "p29": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔ ۔",
#     "p30": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔۔",
#     "p31": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔۔"
# }
# --------------------
# Content of article_2.json:
# {
#     "p1": "",
#     "p2": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم  کرلیے۔",
#     "p3": "وہ 2017 میں لندن میں گرفتار ہوئے جبکہ انہیں 12 مئی 2023 کو امریکا کی تحویل میں دیا گیا۔",
#     "p4": "ملزم نے امریکی مجسٹریٹ جج اسٹیورٹ ڈی آرون کی عدالت میں جرم کا اعتراف کیا۔",
#     "p5": "آصف حفیظ کو امریکی ڈسٹرکٹ جج وکٹر میریو سزا سنائیں گے۔ ملزم نے لندن کی عدالت میں دعویٰ کیا تھا کہ وہ 5 جاسوس ایجنسیوں کیلئے کام کرتا تھا۔",
#     "p6": "منشیات کیس میں بھارتی اداکارہ ممتا کلکرنی اور انکے شوہر وکی گوسوامی بھی ملوث  تھے۔ وکی گوسوامی اور آکاشا برادرز پہلے ہی اس مقدمے میں جرم قبول کرچکے ہیں۔",
#     "p7": "سی ای او واٹر کارپوریشن انجینئر صلاح الدین احمد  نے کہا کہ  بی آر ٹی ٹریک کے نیچے 1958 اور1971 میں ڈالی گئی لائنیں ہیں، بی آر ٹی انتظامیہ کو 35 ملین روپے ہرجانہ ادا کرنے کا کہا ہے۔",
#     "p8": "سینٹرل ڈیولپمنٹ ورکنگ پارٹی (سی ڈی ڈبلیو پی) نے 422 ارب 70 کروڑ لاگت کے 15 ترقیاتی منصوبے منظور کرلیے۔",
#     "p9": "چیئرمین پیپلز پارٹی بلاول بھٹو زرداری نے سانحہِ آرمی پبلک اسکول پشاور کے شہدا کو خراجِ عقیدت پیش کیا۔",
#     "p10": "ایکسپو سینٹر کراچی میں جاری پانچ روزہ عالمی کتب میلے کے دوسرے روز بھی شہریوں کی بڑی تعداد نے کتب میلے میں شرکت کی۔صبح سے ہی بڑی بھی شہریوں کی بڑی تعداد نے شرکت کی۔ صبح سے ہی اسکولز، کالجز اور یونیورسٹی و مدارس کے طلبہ سمیت سماجی تنظیموں، ادبی اور سرکاری شخصیات نے بھی کتب میلے کا دورہ کیا۔",
#     "p11": "محسن نقوی نے کہا کہ پاکستان سفارتکاروں کی حفاظت کیلئے اسپیشل پروٹیکشن یونٹ قائم کر رہا ہے۔",
#     "p12": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔",
#     "p13": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔",
#     "p14": "اسپیکر قومی اسمبلی سردار ایاز صادق نے کہا ہے کہ 16 دسمبر 2014ء کو طلباء اور اساتذہ کی قربانی نے دہشت گردی کے خاتمے کےلیے پوری قوم کو متحد کیا۔",
#     "p15": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔",
#     "p16": "چیئرمین پبلک اکاؤنٹس کمیٹی سندھ نثار کھوڑو نے کہا ہے کہ وفاقی حکومت آئین کی خلاف ورزیوں سے باز رہے۔",
#     "p17": "وزیراعظم شہباز شریف کی فوکل پرسن عائشہ رضا فاروق نے کہا ہے کہ انسداد پولیو مہم کے ذریعے 4 کروڑ 40 لاکھ بچوں کو قطرےپلائے جائیں گے۔",
#     "p18": "وزیراعظم شہبازشریف کے مشیر رانا ثناء اللّٰہ نے کہا ہے کہ پی ٹی آئی کی صوبائی حکومت 3 بار اسلام آباد پر حملہ آور ہوچکی ہے۔",
#     "p19": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔",
#     "p20": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔",
#     "p21": "وزیراعظم شہباز شریف نے رواں سال پولیو کے 60 کیسز سامنے آنےکو انتہائی تشویشناک اور حکومت کے لیے چیلنج قرار دیا ہے۔",
#     "p22": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔۔",
#     "p23": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔ \n\n۔",
#     "p24": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔ ۔",
#     "p25": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔۔",
#     "p26": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔۔"
# }
# --------------------
# Content of article_3.json:
# {
#     "p1": "",
#     "p2": "اسلام آباد اور راولپنڈی میں 16 دسمبر کو عام تعطیل کا اعلان کردیا گیا ہے۔  جڑواں شہروں میں کل تمام تعلیمی ادارے بند رہیں گے۔",
#     "p3": "ڈپٹی کمشنر راولپنڈی حسن وقار چیمہ نے عام تعطیل کا نوٹیفکیشن جاری کردیا۔ انکا کہنا تھا کہ کل ضلع کے تمام تعلیمی ادارے بند رہیں گے۔",
#     "p4": "دریں اثنا اسلام آباد انتظامیہ نے بھی کل تعلیمی ادارے بند رکھنے کا فیصلہ کیا ہے۔",
#     "p5": "ڈپٹی کمشنر اسلام آباد عرفان نواز میمن کے جاری کردہ نوٹیفکیشن کے مطابق اسلام آباد میں بھی کل 16 دسمبر کو تعلیمی ادارے بند رکھنے کا فیصلہ کیا گیا ہے۔",
#     "p6": "نوٹیفکیشن کے مطابق اسلام آباد میں تمام نجی اور سرکاری اسکول 16 دسمبر کو بند رہیں گے۔",
#     "p7": "سی ای او واٹر کارپوریشن انجینئر صلاح الدین احمد  نے کہا کہ  بی آر ٹی ٹریک کے نیچے 1958 اور1971 میں ڈالی گئی لائنیں ہیں، بی آر ٹی انتظامیہ کو 35 ملین روپے ہرجانہ ادا کرنے کا کہا ہے۔",
#     "p8": "سینٹرل ڈیولپمنٹ ورکنگ پارٹی (سی ڈی ڈبلیو پی) نے 422 ارب 70 کروڑ لاگت کے 15 ترقیاتی منصوبے منظور کرلیے۔",
#     "p9": "چیئرمین پیپلز پارٹی بلاول بھٹو زرداری نے سانحہِ آرمی پبلک اسکول پشاور کے شہدا کو خراجِ عقیدت پیش کیا۔",
#     "p10": "ایکسپو سینٹر کراچی میں جاری پانچ روزہ عالمی کتب میلے کے دوسرے روز بھی شہریوں کی بڑی تعداد نے کتب میلے میں شرکت کی۔صبح سے ہی بڑی بھی شہریوں کی بڑی تعداد نے شرکت کی۔ صبح سے ہی اسکولز، کالجز اور یونیورسٹی و مدارس کے طلبہ سمیت سماجی تنظیموں، ادبی اور سرکاری شخصیات نے بھی کتب میلے کا دورہ کیا۔",
#     "p11": "محسن نقوی نے کہا کہ پاکستان سفارتکاروں کی حفاظت کیلئے اسپیشل پروٹیکشن یونٹ قائم کر رہا ہے۔",
#     "p12": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔",
#     "p13": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔",
#     "p14": "اسپیکر قومی اسمبلی سردار ایاز صادق نے کہا ہے کہ 16 دسمبر 2014ء کو طلباء اور اساتذہ کی قربانی نے دہشت گردی کے خاتمے کےلیے پوری قوم کو متحد کیا۔",
#     "p15": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔",
#     "p16": "چیئرمین پبلک اکاؤنٹس کمیٹی سندھ نثار کھوڑو نے کہا ہے کہ وفاقی حکومت آئین کی خلاف ورزیوں سے باز رہے۔",
#     "p17": "وزیراعظم شہباز شریف کی فوکل پرسن عائشہ رضا فاروق نے کہا ہے کہ انسداد پولیو مہم کے ذریعے 4 کروڑ 40 لاکھ بچوں کو قطرےپلائے جائیں گے۔",
#     "p18": "وزیراعظم شہبازشریف کے مشیر رانا ثناء اللّٰہ نے کہا ہے کہ پی ٹی آئی کی صوبائی حکومت 3 بار اسلام آباد پر حملہ آور ہوچکی ہے۔",
#     "p19": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔",
#     "p20": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔",
#     "p21": "وزیراعظم شہباز شریف نے رواں سال پولیو کے 60 کیسز سامنے آنےکو انتہائی تشویشناک اور حکومت کے لیے چیلنج قرار دیا ہے۔",
#     "p22": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔۔",
#     "p23": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔ ۔",
#     "p24": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔ ۔",
#     "p25": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔۔",
#     "p26": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔۔"
# }
# --------------------
# Content of article_4.json:
# {
#     "p1": "",
#     "p2": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔",
#     "p3": "ڈپٹی کمشنر لاہور کی جانب سے چھٹی کے حوالے سے نوٹیفکیشن جاری کر دیا گیا۔",
#     "p4": "نوٹیفکیشن میں کہا گیا ہے کہ لاہور ضلع کے تمام نجی و سرکاری اسکول اور کالجز پیر کو بند رہیں گے۔",
#     "p5": "خیال رہے کہ اسلام آباد اور راولپنڈی میں عام تعطیل کا اعلان کیا گیا ہے۔ جڑواں شہروں میں تمام سرکاری و نجی تعلیمی ادارے بند رہیں گے۔",
#     "p6": "سی ای او واٹر کارپوریشن انجینئر صلاح الدین احمد  نے کہا کہ  بی آر ٹی ٹریک کے نیچے 1958 اور1971 میں ڈالی گئی لائنیں ہیں، بی آر ٹی انتظامیہ کو 35 ملین روپے ہرجانہ ادا کرنے کا کہا ہے۔",
"محسن نقوی نے کہا کہ پاکستان سفارتکاروں کی حفاظت کیلئے اسپیشل پروٹیکشن یونٹ قائم کر رہا ہے۔",
#     "p16": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔",
#     "p17": "اسپیکر قومی اسمبلی سردار ایاز صادق نے کہا ہے کہ 16 دسمبر 2014ء کو طلباء اور اساتذہ کی قربانی نے دہشت گردی کے خاتمے کےلیے پوری قوم کو متحد کیا۔",
#     "p18": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔",
#     "p19": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔",
#     "p20": "چیئرمین پبلک اکاؤنٹس کمیٹی سندھ نثار کھوڑو نے کہا ہے کہ وفاقی حکومت آئین کی خلاف ورزیوں سے باز رہے۔",
#     "p21": "وزیراعظم شہباز شریف کی فوکل پرسن عائشہ رضا فاروق نے کہا ہے کہ انسداد پولیو مہم کے ذریعے 4 کروڑ 40 لاکھ بچوں کو قطرےپلائے جائیں گے۔",
#     "p22": "وزیراعظم شہبازشریف کے مشیر رانا ثناء اللّٰہ نے کہا ہے کہ پی ٹی آئی کی صوبائی حکومت 3 بار اسلام آباد پر حملہ آور ہوچکی ہے۔",
#     "p23": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔",
#     "p24": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔",
#     "p25": "وزیراعظم شہباز شریف نے رواں سال پولیو کے 60 کیسز سامنے آنےکو انتہائی تشویشناک اور حکومت کے لیے چیلنج قرار دیا ہے۔",
#     "p26": "وزیراعلیٰ خیبرپختونخوا علی امین گنڈاپور نے کہا ہے کہ افغانستان کے ساتھ ہمیں مذاکرات کرنے چاہئیں۔",
#     "p27": "وفاقی وزیر اطلاعات عطا تارڑ نے کہا ہے کہ وزیراعلیٰ علی امین گنڈاپور نے چند الزامات لگائے، غیر ملکی میڈیا کو گمراہ کن بریفنگ کا حقیقت سے کوئی تعلق نہیں۔",
#     "p28": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔۔",
#     "p29": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔ ۔",
#     "p30": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔ \n\n۔",
#     "p31": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔ ۔",
#     "p32": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔۔"
# }
# --------------------
# Content of article_6.json:
# {
#     "p1": "",
#     "p2": "",
#     "p3": "",
#     "p4": "",
#     "p5": "کراچی کے علاقے گلستان جوہر کے حسین ہزارہ گوٹھ  میں 18 سالہ لڑکی دعا کی گولی لگنے سے ہلاکت کا معاملہ مشکوک ہوگیا ہے، ورثاء  کی جانب سے متضاد بیانات دیے گئے۔",
#     "p6": "رات گئے گلستان جوہر بلاک 11 حسین ہزارہ گوٹھ بلوچ گراؤنڈ کے قریب گھر میں فائرنگ کے پراسرار واقعے میں 18 سالہ دعا دختر شاہد جاں بحق اور 9 ماہ کی بچی انوشہ دختر طاہر شدید زخمی ہوگئی۔",
#     "p7": "پولیس کا کہنا ہے کہ فائرنگ کے مقام سے کرائم سین یونٹ کی ٹیم شواہد اکھٹا کر رہی ہے،",
#     "p8": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔",
#     "p9": "پولیس کا کہنا ہے کہ فائرنگ کا واقعہ گھر کے اندر پیش آیا یا گھر کے باہر، تحقیقات کر رہے ہیں، ٹیکنیکل سپورٹ کی مدد سے کیس کے تمام پہلوؤں پر تحقیق کر رہے ہیں، ابتدائی تحقیقات مکمل ہونے کے بعد مقدمہ درج کریں گے۔",
#     "p10": "",
#     "p11": "محسن نقوی نے کہا کہ پاکستان سفارتکاروں کی حفاظت کیلئے اسپیشل پروٹیکشن یونٹ قائم کر رہا ہے۔",
#     "p12": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔",
#     "p13": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔",
#     "p14": "اسپیکر قومی اسمبلی سردار ایاز صادق نے کہا ہے کہ 16 دسمبر 2014ء کو طلباء اور اساتذہ کی قربانی نے دہشت گردی کے خاتمے کےلیے پوری قوم کو متحد کیا۔",
#     "p15": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔",
#     "p16": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔",
#     "p17": "چیئرمین پبلک اکاؤنٹس کمیٹی سندھ نثار کھوڑو نے کہا ہے کہ وفاقی حکومت آئین کی خلاف ورزیوں سے باز رہے۔",
#     "p18": "وزیراعظم شہباز شریف کی فوکل پرسن عائشہ رضا فاروق نے کہا ہے کہ انسداد پولیو مہم کے ذریعے 4 کروڑ 40 لاکھ بچوں کو قطرےپلائے جائیں گے۔",
#     "p19": "وزیراعظم شہبازشریف کے مشیر رانا ثناء اللّٰہ نے کہا ہے کہ پی ٹی آئی کی صوبائی حکومت 3 بار اسلام آباد پر حملہ آور ہوچکی ہے۔",
#     "p20": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔",
#     "p21": "وزیراعظم شہباز شریف نے رواں سال پولیو کے 60 کیسز سامنے آنےکو انتہائی تشویشناک اور حکومت کے لیے چیلنج قرار دیا ہے۔",
#     "p22": "وزیراعلیٰ خیبرپختونخوا علی امین گنڈاپور نے کہا ہے کہ افغانستان کے ساتھ ہمیں مذاکرات کرنے چاہئیں۔",
#     "p23": "وفاقی وزیر اطلاعات عطا تارڑ نے کہا ہے کہ وزیراعلیٰ علی امین گنڈاپور نے چند الزامات لگائے، غیر ملکی میڈیا کو گمراہ کن بریفنگ کا حقیقت سے کوئی تعلق نہیں۔",
#     "p24": "پنجاب میں موسمِ سرما میں اسکول یونیفارم پالیسی میں نرمی کردی گئی۔",
#     "p25": "چیئرمین سینیٹ یوسف رضا گیلانی نے کہا ہے کہ پیپلز پارٹی وفاقی کابینہ کا پہلے بھی حصہ نہیں تھی، آئندہ بھی نہیں ہوگی۔",
#     "p26": "مئیر کراچی مرتضی وہاب نے تزین و آرائش کے بعد خالق دینا ہال کا افتتاح کر دیا۔",
#     "p27": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔۔",
#     "p28": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔ ۔",
#     "p29": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔ \n\n۔",
#     "p30": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔ ۔",
#     "p31": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔۔"
# }
# --------------------
# Content of article_7.json:
# {
#     "p1": "",
#     "p2": "وزیراعظم شہباز شریف کے مشیر رانا ثناء اللّٰہ نے کہا ہے کہ پی ٹی آئی کی صوبائی حکومت 3 بار اسلام آباد پر حملہ آور ہوچکی ہے۔",
#     "p3": "فیصل آباد میں تقریب سے خطاب میں رانا ثناء اللّٰہ نے کہا کہ پی ٹی آئی ایک صوبے کی حکومت ملنے کی وجہ سے اسلام آباد پر 3 بار حملہ آور ہو چکی ہے ۔",
#     "p4": "انہوں نے کہا کہ بشریٰ بی بی نے آتے ہوئے کہا کہ پٹھان غیرت مند ہوتے ہیں، پٹھان ساتھ نہیں چھوڑتے، مگر ڈی چوک پہنچنے کے بعد پٹھان تو کھڑے رہے مگر بشریٰ بی بی اور گنڈاپور رفو چکر ہوگئے ۔",
#     "p5": "وزیراعظم کے مشیر نے مزید کہا کہ اگر پی ٹی آئی والے ڈی چوک پر  کھڑے رہتے تو لوگ بھی ان کےساتھ کھڑے رہتے۔",
#     "p6": "ان کا کہنا تھا کہ مدارس رجسٹریشن کے معاملے پر مولانا فضل الرحمان کی بات کی قدر ہے، پارلیمنٹ کے اجلاس میں مسئلہ حل ہوجائے گا، احتجاج کی نوبت نہیں آئے گی ۔",
#     "p7": "رانا ثناء اللّٰہ نے مزید کہا کہ 2017 کے بعد ملک میں گالم گلوچ کی سیاست کو فروغ دیا گیا، نوجوانوں کو صرف یہ سکھایا گیا کہ سیاسی مخالفین کو گالیاں دیں۔",
#     "p8": "انہوں نے کہا کہ  بچوں کو سکھایا گیا کہ فلاں جماعت کے لوگوں کو چور ڈاکو کہا جائے، آتے ہوئے کہا پٹھان غیرتمند ہوتے ہیں، ڈی چوک میں پٹھان کھڑے تھے، لانے والے غائب ہوگئے۔",
#     "p9": "وزیراعظم کے مشیر نے کہا کہ وزیراعلیٰ پنجاب سے کہا پابندیاں لگانے کی ضرورت نہیں تھی، پنجاب میں لوگوں نے نہیں نکلنا۔",
#     "p10": "",
#     "p11": "سی ای او واٹر کارپوریشن انجینئر صلاح الدین احمد  نے کہا کہ  بی آر ٹی ٹریک کے نیچے 1958 اور1971 میں ڈالی گئی لائنیں ہیں، بی آر ٹی انتظامیہ کو 35 ملین روپے ہرجانہ ادا کرنے کا کہا ہے۔",
#     "p12": "سینٹرل ڈیولپمنٹ ورکنگ پارٹی (سی ڈی ڈبلیو پی) نے 422 ارب 70 کروڑ لاگت کے 15 ترقیاتی منصوبے منظور کرلیے۔",
#     "p13": "چیئرمین پیپلز پارٹی بلاول بھٹو زرداری نے سانحہِ آرمی پبلک اسکول پشاور کے شہدا کو خراجِ عقیدت پیش کیا۔",
#     "p14": "ایکسپو سینٹر کراچی میں جاری پانچ روزہ عالمی کتب میلے کے دوسرے روز بھی شہریوں کی بڑی تعداد نے کتب میلے میں شرکت کی۔صبح سے ہی بڑی بھی شہریوں کی بڑی تعداد نے شرکت کی۔ صبح سے ہی اسکولز، کالجز اور یونیورسٹی و مدارس کے طلبہ سمیت سماجی تنظیموں، ادبی اور سرکاری شخصیات نے بھی کتب میلے کا دورہ کیا۔",
#     "p15": "محسن نقوی نے کہا کہ پاکستان سفارتکاروں کی حفاظت کیلئے اسپیشل پروٹیکشن یونٹ قائم کر رہا ہے۔",
#     "p16": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔",
#     "p17": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔",
#     "p18": "اسپیکر قومی اسمبلی سردار ایاز صادق نے کہا ہے کہ 16 دسمبر 2014ء کو طلباء اور اساتذہ کی قربانی نے دہشت گردی کے خاتمے کےلیے پوری قوم کو متحد کیا۔",
#     "p19": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔",
#     "p20": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔",
#     "p21": "چیئرمین پبلک اکاؤنٹس کمیٹی سندھ نثار کھوڑو نے کہا ہے کہ وفاقی حکومت آئین کی خلاف ورزیوں سے باز رہے۔",
#     "p22": "وزیراعظم شہباز شریف کی فوکل پرسن عائشہ رضا فاروق نے کہا ہے کہ انسداد پولیو مہم کے ذریعے 4 کروڑ 40 لاکھ بچوں کو قطرےپلائے جائیں گے۔",
#     "p23": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔",
#     "p24": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔",
#     "p25": "وزیراعظم شہباز شریف نے رواں سال پولیو کے 60 کیسز سامنے آنےکو انتہائی تشویشناک اور حکومت کے لیے چیلنج قرار دیا ہے۔",
#     "p26": "وزیراعلیٰ خیبرپختونخوا علی امین گنڈاپور نے کہا ہے کہ افغانستان کے ساتھ ہمیں مذاکرات کرنے چاہئیں۔",
#     "p27": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔۔",
#     "p28": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔ ۔",
#     "p29": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔ \n\n۔",
#     "p30": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔ ۔",
#     "p31": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔۔",
#     "p32": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔۔"
# }
# --------------------
# Content of article_8.json:
# {
#     "p1": "",
#     "p2": "چیئرمین پبلک اکاؤنٹس کمیٹی سندھ نثار کھوڑو نے کہا ہے کہ وفاقی حکومت آئین کی خلاف ورزیوں سے باز رہے۔",
#     "p3": "لاڑکانہ میں میڈیا سے گفتگو میں پیپلز پارٹی سندھ کے صدر اور چیئرمین پبلک اکاؤنٹس کمیٹی سندھ نے کہا کہ وفاق 18ویں آئینی ترمیم کو رول بیک کرنے کا پلان بنا رہا ہے۔",
#     "p4": "انہوں نے کہا کہ نیشنل فنانس کمیشن (این ایف سی) ایوارڈ میں صوبوں کا حصہ بڑھایا تو جاسکتا ہے کم نہیں کیا جاسکتا ہے۔",
#     "p5": "نثار کھوڑو نے مزید کہا کہ وفاقی حکومت آئین کی خلاف ورزیوں سے باز رہے، سندھ کو اختیار دیا جائے تو ٹیکسز وصول کر کے وفاق کو دے سکتے ہیں ۔",
#     "p6": "محسن نقوی نے کہا کہ پاکستان سفارتکاروں کی حفاظت کیلئے اسپیشل پروٹیکشن یونٹ قائم کر رہا ہے۔",
#     "p7": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔",
#     "p8": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔",
#     "p9": "اسپیکر قومی اسمبلی سردار ایاز صادق نے کہا ہے کہ 16 دسمبر 2014ء کو طلباء اور اساتذہ کی قربانی نے دہشت گردی کے خاتمے کےلیے پوری قوم کو متحد کیا۔",
#     "p10": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔",
#     "p11": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔",
#     "p12": "وزیراعظم شہباز شریف کی فوکل پرسن عائشہ رضا فاروق نے کہا ہے کہ انسداد پولیو مہم کے ذریعے 4 کروڑ 40 لاکھ بچوں کو قطرےپلائے جائیں گے۔",
#     "p13": "وزیراعظم شہبازشریف کے مشیر رانا ثناء اللّٰہ نے کہا ہے کہ پی ٹی آئی کی صوبائی حکومت 3 بار اسلام آباد پر حملہ آور ہوچکی ہے۔",
#     "p14": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔",
#     "p15": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔",
#     "p16": "وزیراعظم شہباز شریف نے رواں سال پولیو کے 60 کیسز سامنے آنےکو انتہائی تشویشناک اور حکومت کے لیے چیلنج قرار دیا ہے۔",
#     "p17": "وزیراعلیٰ خیبرپختونخوا علی امین گنڈاپور نے کہا ہے کہ افغانستان کے ساتھ ہمیں مذاکرات کرنے چاہئیں۔",
#     "p18": "وفاقی وزیر اطلاعات عطا تارڑ نے کہا ہے کہ وزیراعلیٰ علی امین گنڈاپور نے چند الزامات لگائے، غیر ملکی میڈیا کو گمراہ کن بریفنگ کا حقیقت سے کوئی تعلق نہیں۔",
#     "p19": "پنجاب میں موسمِ سرما میں اسکول یونیفارم پالیسی میں نرمی کردی گئی۔",
#     "p20": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔۔",
#     "p21": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔ ۔",
#     "p22": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔ \n\n۔",
#     "p23": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔ ۔",
#     "p24": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔۔",
#     "p25": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔۔"
# }
# --------------------
# Content of article_9.json:
# {
#     "p1": "",
#     "p2": "کراچی واٹر بورڈ کارپوریشن کے چیف ایگزیکٹو آفیسر انجینئر صلاح الدین احمد نے اعتراف کیا ہے کہ اس وقت کراچی کے 70 فیصد علاقے کو پانی کی قلت کا سامنا ہے۔",
#     "p3": "کراچی میں میڈیا سے گفتگو کرتے ہوئے انجینئر صلاح الدین احمد نے کہا کہ  یونیورسٹی روڈ پر ٹوٹی پانی کی پائپ لائن کی مرمت بدھ تک ہونے کا امکان ہے۔",
#     "p4": "انہوں نے بی آر ٹی کنٹریکٹر پر پائپ ٹوٹنے کا الزام لگاتے ہوئے کہا کہ کنٹریکٹر کو تمام نقشے فراہم کیے جا چکے تھے۔ ترقیاتی کام کے دوران احتیاطی تقاضے پورے کرنا ضروری تھا، بی آر ٹی منصوبے پر تمام اداروں کو مل کر کام کرنے کی ضرورت ہے۔",
#     "p5": "راشد منہاس روڈ پر جوہر موڑ کے قریب سیوریج کا پانی جمع ہونے سے ٹریفک کی روانی متاثر ہوگئی، جوہر موڑ سے نیپا جانے والے ٹریک پر ٹریفک جام ہوگیا۔",
#     "p6": "",
#     "p7": "سی ای او واٹر کارپوریشن انجینئر صلاح الدین احمد  نے کہا کہ  بی آر ٹی ٹریک کے نیچے 1958 اور 1971 میں ڈالی گئی لائنیں ہیں، بی آر ٹی انتظامیہ کو 35 ملین روپے ہرجانہ ادا کرنے کا کہا ہے۔",
#     "p8": "انہوں نے کہا کہ غیر قانونی ہائیڈرنٹس کے خلاف کارروائیاں جاری ہیں، نیپا اور دیگر سرکاری ہائیڈرنٹس کی مدد سے شہریوں کو پانی فراہم کر رہے ہیں۔ 245 سے زائد غیر قانونی ہائیڈرنٹس کو گرایا جا چکا ہے۔",
#     "p9": "ایم ڈی واٹر کارپوریشن نے کہا کہ شہر میں اس وقت 5500 واٹر ٹینکر چل رہے ہیں۔ 3600 سے زائد واٹر ٹینکروں کو ہم نے رجسٹرڈ کر لیا ہے جن کا تمام ریکارڈ ہمارے پاس موجود ہے۔",
#     "p10": "سینٹرل ڈیولپمنٹ ورکنگ پارٹی (سی ڈی ڈبلیو پی) نے 422 ارب 70 کروڑ لاگت کے 15 ترقیاتی منصوبے منظور کرلیے۔",
#     "p11": "چیئرمین پیپلز پارٹی بلاول بھٹو زرداری نے سانحہِ آرمی پبلک اسکول پشاور کے شہدا کو خراجِ عقیدت پیش کیا۔",
#     "p12": "ایکسپو سینٹر کراچی میں جاری پانچ روزہ عالمی کتب میلے کے دوسرے روز بھی شہریوں کی بڑی تعداد نے کتب میلے میں شرکت کی۔صبح سے ہی بڑی بھی شہریوں کی بڑی تعداد نے شرکت کی۔ صبح سے ہی اسکولز، کالجز اور یونیورسٹی و مدارس کے طلبہ سمیت سماجی تنظیموں، ادبی اور سرکاری شخصیات نے بھی کتب میلے کا دورہ کیا۔",
#     "p13": "محسن نقوی نے کہا کہ پاکستان سفارتکاروں کی حفاظت کیلئے اسپیشل پروٹیکشن یونٹ قائم کر رہا ہے۔",
#     "p14": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔",
#     "p15": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔",
#     "p16": "اسپیکر قومی اسمبلی سردار ایاز صادق نے کہا ہے کہ 16 دسمبر 2014ء کو طلباء اور اساتذہ کی قربانی نے دہشت گردی کے خاتمے کےلیے پوری قوم کو متحد کیا۔",
#     "p17": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔",
#     "p18": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔",
#     "p19": "چیئرمین پبلک اکاؤنٹس کمیٹی سندھ نثار کھوڑو نے کہا ہے کہ وفاقی حکومت آئین کی خلاف ورزیوں سے باز رہے۔",
#     "p20": "وزیراعظم شہباز شریف کی فوکل پرسن عائشہ رضا فاروق نے کہا ہے کہ انسداد پولیو مہم کے ذریعے 4 کروڑ 40 لاکھ بچوں کو قطرےپلائے جائیں گے۔",
#     "p21": "وزیراعظم شہبازشریف کے مشیر رانا ثناء اللّٰہ نے کہا ہے کہ پی ٹی آئی کی صوبائی حکومت 3 بار اسلام آباد پر حملہ آور ہوچکی ہے۔",
#     "p22": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔",
#     "p23": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔",
#     "p24": "وزیراعظم شہباز شریف نے رواں سال پولیو کے 60 کیسز سامنے آنےکو انتہائی تشویشناک اور حکومت کے لیے چیلنج قرار دیا ہے۔",
#     "p25": "وزیراعلیٰ خیبرپختونخوا علی امین گنڈاپور نے کہا ہے کہ افغانستان کے ساتھ ہمیں مذاکرات کرنے چاہئیں۔",
#     "p26": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔۔",
#     "p27": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔ ۔",
#     "p28": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔ \n\n۔",
#     "p29": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔ ۔",
#     "p30": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔۔",
#     "p31": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔۔"
# }
# --------------------
# Content of article_10.json:
# {
#     "p1": "",
#     "p2": "ایکسپو سینٹر کراچی میں جاری پانچ روزہ عالمی کتب میلے کے دوسرے روز بھی شہریوں کی بڑی تعداد نے کتب میلے میں شرکت کی۔ صبح سے ہی اسکولز، کالجز اور یونیورسٹی و مدارس کے طلبہ سمیت سماجی تنظیموں، ادبی اور سرکاری شخصیات نے بھی کتب میلے کا دورہ کیا۔",
#     "p3": "ڈائریکٹریٹ آف انسپکیشن اینڈ رجسٹریشن انسٹی ٹیوشن کی ایڈیشنل ڈائریکٹر رافعہ جاوید، ایس ایس پی ایسٹ ڈاکٹر فرخ رضا، ڈی ایس پی ایسٹ ہیڈ کواٹر زرین منظور شاہ، جناح ٹاؤن کے چیئرمین رضوان عبدالسمیع نے بھی کتب میلے کا دورہ کیا۔",
#     "p4": "عالمی کتب میلے میں ترکیہ کی جانب سے لگایا جانے والا اسٹال لوگوں کی توجہ کا مرکز رہا جہاں ترکیہ کی جانب سے مفت اسلامی کتابیں شہریوں میں تقسیم کی گئیں۔ شہریوں نے بھی ترک کتب میں دلچسپی کا اظہار کیا۔",
"لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔",
#     "p16": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔",
#     "p17": "اسپیکر قومی اسمبلی سردار ایاز صادق نے کہا ہے کہ 16 دسمبر 2014ء کو طلباء اور اساتذہ کی قربانی نے دہشت گردی کے خاتمے کےلیے پوری قوم کو متحد کیا۔",
#     "p18": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔",
#     "p19": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔",
#     "p20": "چیئرمین پبلک اکاؤنٹس کمیٹی سندھ نثار کھوڑو نے کہا ہے کہ وفاقی حکومت آئین کی خلاف ورزیوں سے باز رہے۔",
#     "p21": "وزیراعظم شہباز شریف کی فوکل پرسن عائشہ رضا فاروق نے کہا ہے کہ انسداد پولیو مہم کے ذریعے 4 کروڑ 40 لاکھ بچوں کو قطرےپلائے جائیں گے۔",
#     "p22": "وزیراعظم شہبازشریف کے مشیر رانا ثناء اللّٰہ نے کہا ہے کہ پی ٹی آئی کی صوبائی حکومت 3 بار اسلام آباد پر حملہ آور ہوچکی ہے۔",
#     "p23": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔",
#     "p24": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔",
#     "p25": "وزیراعظم شہباز شریف نے رواں سال پولیو کے 60 کیسز سامنے آنےکو انتہائی تشویشناک اور حکومت کے لیے چیلنج قرار دیا ہے۔",
#     "p26": "وزیراعلیٰ خیبرپختونخوا علی امین گنڈاپور نے کہا ہے کہ افغانستان کے ساتھ ہمیں مذاکرات کرنے چاہئیں۔",
#     "p27": "وفاقی وزیر اطلاعات عطا تارڑ نے کہا ہے کہ وزیراعلیٰ علی امین گنڈاپور نے چند الزامات لگائے، غیر ملکی میڈیا کو گمراہ کن بریفنگ کا حقیقت سے کوئی تعلق نہیں۔",
#     "p28": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔۔",
#     "p29": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔ ۔",
#     "p30": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔ \n\n۔",
#     "p31": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔ ۔",
#     "p32": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔۔",
#     "p33": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔۔"
# }
# --------------------
# Content of article_11.json:
# {
#     "p1": "",
#     "p2": "بھارتی کرکٹ ٹیم کے فاسٹ بولر جسپریت بمرا نے سابق کپتان کپل دیو کا ریکارڈ توڑ دیا۔",
#     "p3": "برسبین میں کھیلے جانیوالے تیسرے ٹیسٹ میں بھارتی فاسٹ بولر جسپریت بمرا نے آسٹریلیا کے خلاف تیسرے ٹیسٹ کے دوسرے دن شاندار کارکردگی کا مظاہرہ کیا، انہوں نے 72 رنز دے کر 5 وکٹیں حاصل کیں۔",
#     "p4": "جسپریت بمرا نے 12ویں مرتبہ پانچ وکٹیں حاصل کیں جبکہ جنوبی افریقہ، انگلینڈ، نیوزی لینڈ اور آسٹریلیا (سینا ممالک) کے خلاف شاندار بولنگ کرتے ہوئے بمرا نے 8ویں مرتبہ 5 وکٹیں لینے کا کارنامہ انجام دیا ہے۔",
#     "p5": "بھارتی کرکٹ ٹیم کے فاسٹ بولر جسپریت بمرا نے اس اعزاز کے ساتھ بھارت کے سابق آل راؤنڈر اور 1983 کے ورلڈکپ کی فاتح ٹیم کے کپتان کپل دیو کا ریکارڈ بھی توڑ دیا ہے، جنہوں نے سینا ممالک میں 7 مرتبہ پانچ یا اس سے زیادہ وکٹیں حاصل کی تھیں۔",
#     "p6": "بمراہ نے اس اعزاز کے ساتھ بھارت کے لیجنڈری آل راؤنڈر کپل دیو کا ریکارڈ توڑ دیا، جو اس فہرست میں 7 پانچ وکٹوں کے ساتھ دوسرے نمبر پر ہیں۔",
#     "p7": "",
#     "p8": "خیال رہے کہ برسبین ٹیسٹ کے دوسرے دن بھارت کے خلاف آسٹریلوی بیٹرز نے جارحانہ بیٹنگ کرتے ہوئے پہلی اننگز میں 7 وکٹوں کے نقصان پر  405  رنز بنا لیے۔",
#     "p9": "اسٹیو اسمتھ  نے 101 رنز کی اننگز کھیلی، ٹریوس ہیڈ نے 152 رنز بنائے، ایلکس کیری 45 رنز بنا کر ناقابل شکست رہے۔",
#     "p10": "بھارت کی جانب سے جسپریت بمرا  نے 5  کھلاڑی آؤٹ کیے، ٹیسٹ کے پہلے روز بارش کی وجہ سے صرف 13 اعشاریہ 2 اوورز کا کھیل ہوسکا تھا۔",
#     "p11": "",
#     "p12": "جھل مگسی آف روڈ ڈیزرٹ چیلنج ریلی میں مگسی فیملی نے میدان مار لیا، ابتدائی تینوں پوزیشنز مگسی فیملی کے نام رہی ۔",
#     "p13": "عماد وسیم، محمد عامر کے بعد اب فاسٹ بولر محمد عرفان نے بھی انٹرنیشنل کرکٹ سے ریٹائرمنٹ کا اعلان کردیا۔",
#     "p14": "بھارت کی خاتون بیڈمنٹن کھلاڑی پُسرلا وینکٹا سندھو نے منگنی کرلی۔",
#     "p15": "قومی کرکٹ ٹیم کے سابق کپتان شاہد خان آفریدی آف روڈ ریلی دیکھنے جھل مگسی کے ٹریک پر آگئے۔",
#     "p16": "چیمپئنز ٹرافی کے معاملے پر اب کسی قسم کی کوئی پیچیدگی نہیں رہی،  چیمپئنز ٹرافی کے معاملات پر معاہدوں کا کام حتمی مرحلے میں پہنچ چکا ہے۔",
#     "p17": "تین میچوں پر مشتمل سیریز میں جنوبی افریقا کو دو صفر کی فیصلہ کن برتری حاصل ہے۔",
#     "p18": "پاکستان سپر لیگ (پی ایس ایل) 10 سے متعلق روزانہ کی بنیاد پر اجلاس اور مشاورت جاری ہے۔",
#     "p19": "تین میچوں کی سیریز میں جنوبی افریقہ کو پہلے ہی 0-2 کی ناقابلِ شکست برتری حاصل ہے۔",
#     "p20": "کرکٹ آسٹریلیا کوصرف 10 گیندیں کم ہونے پر 10 لاکھ ڈالرز کے نقصان کا بڑا دھچکا لگ گیا۔",
#     "p21": "انٹرنیشنل کرکٹ کونسل (آئی سی سی) نے افغانستان کے آل راؤنڈر گلبدین نائب پر جرمانہ عائد کر دیا۔",
#     "p22": "پاکستانی ویمنز انڈر 19 ٹیم پریکٹس سیشن کے لیے کوالالمپور کے سلنگور ٹرف کلب پہنچ گئی ہے۔",
#     "p23": "کراچی ٹیپ بال پریمیئر لیگ (کے ٹی پی ایل) آج سے شروع ہو رہی ہے۔",
#     "p24": "جھل مگسی آف روڈ ڈیزرٹ چیلنج ریلی میں علی مگسی کی گاڑی حادثے کا شکار ہو گئی۔",
#     "p25": "پاکستان کے آل راؤنڈر عماد وسیم کے بعد فاسٹ بولر محمد عامر نے بھی انٹرنیشنل کرکٹ سے ریٹائرمنٹ کا اعلان کر دیا۔",
#     "p26": "ریس کے دوران شرکاء کے لئے روایتی کھانے بھی تیار کئے گئے۔",
#     "p27": "پاکستان کرکٹ ٹیم کے اسٹار بیٹر بابر اعظم نے ٹی 20 کرکٹ میں نئی تاریخ رقم کردی۔",
#     "p28": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔۔",
#     "
ائی کی ٹاسک فورس نے مہنگے ایندھن پر چلنے والے پاور پلانٹس جیسے ہائی اسپیڈ ڈیزل (HSD)، فرنس آئل (RFO) اور کچھ RLNG پاور پلانٹس کے ساتھ مذاکرات شروع کر رکھے ہیں ۔ مہنگی بجلی بنانے والے 26 فرنس آئل پاور پلانٹس میں سے 14 کے ساتھ حکومتی ٹاسک فورس کے مذاکرات کامیاب ہو گئے ہیں جن کے تحت کیپسٹی پیمنٹ کی ادائیگی ختم ہو گئی ہے ۔ ان سے جتنی بجلی حکومت لے گی اتنی ہی ادائیگی ہوا کریگی ۔ 12 فرنس آئل پر چلنے والے آئی پی پیز کے ساتھ ٹاسک فورس کے مذاکرات جاری ہیں جو جلد مکمل ہونگے ۔ مہنگی ترین بجلی پیدا کرنے والا پاور پلانٹ ہالمور پاور ہے جو HSD پر چلتا ہے اور 61.23 روپے فی یونٹ کے حساب سے بجلی پیدا کرتا ہےجبکہ سب سے کم لاگت پر بجلی پیدا کرنے والا پاور پلانٹ UCH ہے جو گیس پر چلتا ہے اور 3.11 روپے فی یونٹ کے حساب سے بجلی فراہم کرتا ہے۔ 14 آر ایف او ( رزول فرنیس آئیل )پر چلنے والے پاور پلانٹس کے ساتھ \"ٹیک اینڈ پے\" ( TAKE & PAY)کے اصول پر مذاکرات مکمل کر لئے گئے ہیں جبکہ دیگر پاور پلانٹس کے ساتھ بات چیت جاری ہے۔ مہنگے ترین پاور پلانٹس میں ہالمور پاور شامل ہے جو HSD پر 61.2 روپے فی یونٹ کے حساب سے بجلی پیدا کر رہا ہے، اس کے بعد سیف پاور اور سفائر الیکٹرک کمپنی HSD پر 60.8 روپے فی یونٹ بجلی پیدا کر رہے ہیں۔ اورینٹ پاور کمپنی HSD پر 60.2 روپے فی یونٹ کے حساب سے بجلی پیدا کر رہی ہے جبکہ اینگرو پاورجن HSD پر 55.2 روپے فی یونٹ بجلی پیدا کر رہا ہے۔ این پی پی ایم سی - بلوکی (CC) اور قیو اے ٹی پی ایل بھیکی (CC) HSD پر بالترتیب 53.2 اور 51.6 روپے فی یونٹ کے حساب سے بجلی فراہم کر رہے ہیں۔",
#     "p3": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔۔",
#     "p4": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔ ۔",
#     "p5": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔ \n\n۔",
#     "p6": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔ ۔",
#     "p7": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔۔",
#     "p8": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔۔"
# }
# --------------------
# Content of article_64.json:
# {
#     "p1": "",
#     "p2": "اسلام اآ باد ( رانا غلام قادر )گریڈ19میں ترقی کیلئے لازمی MCMC کورس، 14افسروں کی نامزدگی منسوخ ،PAS کے شہریار احمد، قراۃ العین ، خرم پرویز، حسن وقار ، کیپٹن (ر) شمیر اقبال، اویس مشتاق ٗحناا ارشد ،عثمان اشرف ،پولیس سروس آف پاکستان کے وسیم ریاض، تصور اقبال، محمد عیسیٰ خان، محمد ہاشم اور محمد بلوچ اور محمد عمران کے نام واپس ، سرکاری افسران کی گریڈ 18سے 19میں ترقی کیلئے لازمی 42ویں مِڈ کیریئر منیجمنٹ کورس کیلئے نامزد افسران میں ایک بار پھر ردوبدل کیا گیا ۔ پاکستان ایڈمنسٹریٹو سروس کے 8 اور پولیس س
ی سروس کے محض 13 افسران ہی کامیاب ہو سکے۔ فیڈرل پبلک سروس کمیشن کی جانب سے پاکستان ایڈمنسٹریٹو سروس میں شمولیت کیلئے 23 ستمبر 2024 سے 24 ستمبر 2024تک منعقدہ پروونشل مینجمنٹ سروسز (پی ایم ایس) پروونشل سول سروسز (پی سی ایس) کے سبجیکٹ ایگزامینیشن کے تحریری حصے کے نتائج کے مطابق 26 اآسامیوں کیلئے 40 امیدواروں نے اپلائی کیا، 19امیدوار تحریری امتحان میں غیر حاضر رہے۔",
#     "p3": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔۔",
#     "p4": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔ ۔",
#     "p5": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔ \n\n۔",
#     "p6": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔ ۔",
#     "p7": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔۔",
#     "p8": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔۔"
# }
# --------------------
# Content of article_68.json:
# {
#     "p1": "",
#     "p2": "اسلام آباد (اے پی پی) حکومت پاکستان اور ایشیائی ترقیاتی بینک (اے ڈی بی)کے درمیان انٹیگریٹڈ سوشل پروٹیکشن ڈویلپمنٹ پروگرام (آئی ایس پی ڈی پی) کی اضافی فنانسنگ کے لیے 33 کروڑ امریکی ڈالر کے قرض کے معاہدے پر دستخط ہوگئے ہیں۔ معاہدے پر پاکستان کی جانب سے سیکرٹری اقتصادی امور ڈاکٹر کاظم نیاز اور اے ڈی بی کی جانب سے کنٹری ڈائریکٹر ایما فین نے دستخط کئے۔ یہ پروگرام بے نظیر انکم سپورٹ پروگرام (بی آئی ایس پی) کے ذریعے پاکستان میں سماجی تحفظ کے نظام کو مضبوط اور وسعت دینے کے لیے جاری اے ڈی بی کی مالی امداد سے چلنے والے پروگرام کا حصہ ہے۔",
#     "p3": "خواجہ آصف نے کہا کہ بانی پی ٹی آئی کے جیل سے کچھ بیان آتے ہیں، بہنوں کے لاہور سے کچھ اور کےپی سے بشریٰ بی بی کے کچھ بیانات آتے ہیں، ان کے بیانات میں کوئی ہم آہنگی نہیں۔۔",
#     "p4": "لاہور کے سونے کے تاجر آصف حفیظ نے امریکا میں منشیات اسمگلنگ کا اعتراف کیا ہے۔ آصف حفیظ نے ہیروئن، میتھمفیٹائن اور چرس امریکا اسمگل کرنے کے الزامات تسلیم کرلیے۔ ۔",
#     "p5": "راولپنڈی میں 16 دسمبر کو ضلع بھرمیں عام تعطیل کا اعلان کر دیا گیا ہے،  اور ضلع بھر میں کل تمام تعلیمی ادارے بند رہیں گے۔ \n\n۔",
#     "p6": "لاہور ضلع میں نجی و سرکاری اسکولوں اور کالجوں میں کل چھٹی کا اعلان کیا گیا ہے۔ ۔",
#     "p7": "حکومتی اتحادی متحدہ قومی موومنٹ (ایم کیو ایم) پاکستان کےسربراہ خالد مقبول صدیقی نے کہا ہے کہ میں نے نہیں کہا ہم حکومت چھوڑ رہے ہیں۔۔",
#     "p8": "پولیس حکام کا کہنا ہے کہ ورثاء نے واقعے کے بعد متضاد بیانات دیے، ورثاء کی جانب سے پولیس سے عدم تعاون پر معاملہ مشکوک ہو رہا ہے، انہوں نے تاحال مقدمہ درج کروانے کی حامی بھی نہیں بھری۔۔"
# }
# --------------------

# %%
# Import required librimport os
import json
import re
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from pyngrok import ngrok



# Write the Streamlit app to app.py
with open("app.py", "w") as f:
    f.write("""
import re
import os
import json
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import streamlit as st

# Function to handle whitespace
WHITESPACE_HANDLER = lambda k: re.sub('\\s+', ' ', re.sub('\\n+', ' ', k.strip() if hasattr(k, 'strip') else str(k)))

# Model initialization
model_name = "csebuetnlp/mT5_multilingual_XLSum"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Function to generate summary for a single text
def generate_summary(text):
    input_ids = tokenizer(
        [WHITESPACE_HANDLER(text)],
        return_tensors="pt",
        padding="max_length",
        truncation=True,
        max_length=512
    )["input_ids"]

    output_ids = model.generate(
        input_ids=input_ids,
        max_length=84,
        no_repeat_ngram_size=2,
        num_beams=4
    )[0]

    summary = tokenizer.decode(
        output_ids,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=False
    )

    return summary

# Function to split long text and summarize each part
def split_and_summarize(text, max_chunk_size=512):
    chunks = [text[i:i + max_chunk_size] for i in range(0, len(text), max_chunk_size)]
    summaries = [generate_summary(chunk) for chunk in chunks]
    return ' '.join(summaries)

# Function to process a single article
def process_article(filepath):
    with open(filepath, 'r', encoding='utf-8') as f:
        json_data = json.load(f)

    content_paragraphs = [value for key, value in json_data.items() if key != 'p1']
    content_text = ' '.join(content_paragraphs)

    # Check if content exceeds max length and split if necessary
    if len(tokenizer.encode(content_text)) > 512:
        summary = split_and_summarize(content_text)
    else:
        summary = generate_summary(content_text)

    return summary

# Streamlit app code
st.title("Jang News Summaries")
st.sidebar.title("Configuration")
article_dir = st.sidebar.text_input("Articles Directory", value="jang_articles")

# Ensure the directory exists
if os.path.exists(article_dir):
    # Natural sort of article files
    def natural_sort_key(s):
        return [int(text) if text.isdigit() else text.lower() for text in re.split('(\\d+)', s)]

    article_files = sorted(
        [filename for filename in os.listdir(article_dir) if filename.endswith('.json')],
        key=natural_sort_key
    )

    # Display summaries for each file
    for filename in article_files:
        filepath = os.path.join(article_dir, filename)
        try:
            with st.spinner(f"Processing {filename}..."):
                summary = process_article(filepath)
                st.subheader(filename)
                st.write(summary)
                st.write("---")  # Separator
        except Exception as e:
            st.error(f"Error processing {filename}: {e}")
else:
    st.error(f"Directory '{article_dir}' does not exist. Please check the path.")
""")

# Run the Streamlit app
# !ngrok authtoken <YOUR AUTHTOKEN>
# Set up ngrok for exposing the Streamlit app
ngrok.kill()  # Close any existing tunnels to avoid conflicts
public_url = ngrok.connect(addr="8501").public_url  # Specify the port with 'addr'
print(f"Streamlit app is running at: {public_url}")


# Run the Streamlit app
# !streamlit run app.py --server.port 8501 --server.enableCORS false --server.headless true
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# Streamlit app is running at: https://61c7-34-125-252-77.ngrok-free.app
# 2024-12-15 17:06:03.080
# Warning: the config option 'server.enableCORS=false' is not compatible with 'server.enableXsrfProtection=true'.
# As a result, 'server.enableCORS' is being overridden to 'true'.
#
# More information:
# In order to protect against CSRF attacks, we send a cookie with each request.
# To do so, we must specify allowable origins, which places a restriction on
# cross-origin resource sharing.
#
# If cross origin resource sharing is required, please disable server.enableXsrfProtection.
#
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.125.252.77:8501
#
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:561: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# 2024-12-15 17:08:16.280361: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-15 17:08:16.296663: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-15 17:08:16.301496: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-15 17:08:16.314378: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-15 17:08:17.439593: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
